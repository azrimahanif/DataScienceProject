# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("project_data.csv")

# %%
data.index
# Out:
# RangeIndex(start=0, stop=2894, step=1)

# %%
data.columns
# Out:
# Index(['id', 'title', 'component', 'owner', 'priority', 'status', 'reason',
#        'lab', 'org_unit', 'program', 'customer_contact', 'updated_by',
#        'submitted_date', 'closed_date', 'acknowledged_date', 'eta',
#        'eta_request', 'category', 'cell_id'],
#       dtype='object')

# %%
data.empty
# Out:
# False

# %%
data.info
# Out:
# <bound method DataFrame.info of                                                      id  \
# 0     =HYPERLINK("https://hsdes.intel.com/resource/1...
# 1     =HYPERLINK("https://hsdes.intel.com/resource/1...
# 2     =HYPERLINK("https://hsdes.intel.com/resource/1...
# 3     =HYPERLINK("https://hsdes.intel.com/resource/1...
# 4     =HYPERLINK("https://hsdes.intel.com/resource/1...
# ...                                                 ...
# 2889  =HYPERLINK("https://hsdes.intel.com/resource/1...
# 2890  =HYPERLINK("https://hsdes.intel.com/resource/1...
# 2891  =HYPERLINK("https://hsdes.intel.com/resource/1...
# 2892  =HYPERLINK("https://hsdes.intel.com/resource/1...
# 2893  =HYPERLINK("https://hsdes.intel.com/resource/1...
#
#                                                   title  \
# 0     [50.3D][TGL] RELEASE CELL FOR WO EXECUTION,APP...
# 1     [WW50.2][REMOTE SUPPORT][GLK][APPV0001C] Need ...
# 2     [WW50.2][REMOTE SUPPORT][GLK][APPV0001C] Need ...
# ...

# %%
data.dtypes
# Out:
# id                    object
# title                 object
# component             object
# owner                 object
# priority              object
# status                object
# reason                object
# lab                   object
# org_unit              object
# program               object
# customer_contact      object
# updated_by            object
# submitted_date        object
# closed_date           object
# acknowledged_date     object
# eta                   object
# eta_request           object
# category              object
# cell_id              float64
# dtype: object

# %%
data
# Out:
#                                                      id  \
# 0     =HYPERLINK("https://hsdes.intel.com/resource/1...
# 1     =HYPERLINK("https://hsdes.intel.com/resource/1...
# 2     =HYPERLINK("https://hsdes.intel.com/resource/1...
# 3     =HYPERLINK("https://hsdes.intel.com/resource/1...
# 4     =HYPERLINK("https://hsdes.intel.com/resource/1...
# ...                                                 ...
# 2889  =HYPERLINK("https://hsdes.intel.com/resource/1...
# 2890  =HYPERLINK("https://hsdes.intel.com/resource/1...
# 2891  =HYPERLINK("https://hsdes.intel.com/resource/1...
# 2892  =HYPERLINK("https://hsdes.intel.com/resource/1...
# 2893  =HYPERLINK("https://hsdes.intel.com/resource/1...
#
#                                                   title  \
# 0     [50.3D][TGL] RELEASE CELL FOR WO EXECUTION,APP...
# 1     [WW50.2][REMOTE SUPPORT][GLK][APPV0001C] Need ...
# 2     [WW50.2][REMOTE SUPPORT][GLK][APPV0001C] Need ...
# 3     [WW48.2[REMOTE SUPPORT] [JSL+]Please collect t...
# ...
